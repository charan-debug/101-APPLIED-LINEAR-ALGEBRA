# %%
# Function to create a matrix
def create_matrix(rows, cols):
    matrix = []
    for i in range(rows):
        row = []
        for j in range(cols):
            element = float(input("Enter value for matrix[{}][{}]: ".format(i, j)))
            row.append(element)
        matrix.append(row)
    return matrix

# Function to add two matrices
def m_addition(matrix1, matrix2):
    result = []
    for i in range(len(matrix1)):
        row = []
        for j in range(len(matrix1[0])):
            element = matrix1[i][j] + matrix2[i][j]
            row.append(element)
        result.append(row)
    return result

# Function to subtract two matrices
def m_subtraction(matrix1, matrix2):
    result = []
    for i in range(len(matrix1)):
        row = []
        for j in range(len(matrix1[0])):
            element = matrix1[i][j] - matrix2[i][j]
            row.append(element)
        result.append(row)
    return result

# Function to multiply two matrices
def m_multiplication(matrix1, matrix2):
    rows1 = len(matrix1)
    cols1 = len(matrix1[0])
    rows2 = len(matrix2)
    cols2 = len(matrix2[0])
    
    # Check if multiplication is possible
    if cols1 != rows2:
        print("Error: Incompatible matrix sizes for multiplication.")
        return
    
    result = []
    for i in range(rows1):
        row = []
        for j in range(cols2):
            element = 0
            for k in range(cols1):
                element += matrix1[i][k] * matrix2[k][j]
            row.append(element)
        result.append(row)
    return result

# Get matrix input from user
rows = int(input("Enter the number of rows: "))
cols = int(input("Enter the number of columns: "))

# Creating the first matrix
print("Enter the values for the first matrix:")
matrix1 = create_matrix(rows, cols)

# Creating the second matrix
print("Enter the values for the second matrix:")
matrix2 = create_matrix(rows, cols)

# Perform matrix addition,subtraction,multiplication
addition_result = m_addition(matrix1, matrix2)
subtraction_result = m_subtraction(matrix1, matrix2)
multiplication_result = m_multiplication(matrix1, matrix2)

# Print the results
print("\nAddition Result is:")
for row in addition_result:
    print(row)

print("\nSubtraction Result is:")
for row in subtraction_result:
    print(row)

print("\nMultiplication Result is:")
for row in multiplication_result:
    print(row)
# Out:
# Enter the number of rows: 3
# Enter the number of columns: 3
# Enter the values for the first matrix:
# Enter value for matrix[0][0]: 1
# Enter value for matrix[0][1]: 2
# Enter value for matrix[0][2]: 3
# Enter value for matrix[1][0]: 4
# Enter value for matrix[1][1]: 5
# Enter value for matrix[1][2]: 6
# Enter value for matrix[2][0]: 7
# Enter value for matrix[2][1]: 8
# Enter value for matrix[2][2]: 9
# Enter the values for the second matrix:
# Enter value for matrix[0][0]: 3
# Enter value for matrix[0][1]: 1
# Enter value for matrix[0][2]: 2
# Enter value for matrix[1][0]: 1
# Enter value for matrix[1][1]: 2
# Enter value for matrix[1][2]: 3
# Enter value for matrix[2][0]: 1
# Enter value for matrix[2][1]: 2
# Enter value for matrix[2][2]: 3
#
# Addition Result is:
# [4.0, 3.0, 5.0]
# [5.0, 7.0, 9.0]
# [8.0, 10.0, 12.0]
#
# Subtraction Result is:
# [-2.0, 1.0, 1.0]
# [3.0, 3.0, 3.0]
# [6.0, 6.0, 6.0]
#
# Multiplication Result is:
# [8.0, 11.0, 17.0]
# [23.0, 26.0, 41.0]
# ...
